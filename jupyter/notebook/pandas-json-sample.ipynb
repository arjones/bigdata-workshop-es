# %% [markdown]
# ### Manipuling a JSON with Pandas

# %%
import json
with open('/dataset/global-temperature-1880-2016.json') as f:
    datum = json.load(f)

# %%
results = []

data_map = datum['data']
for (k, v) in data_map.items():
    results.append([k, float(v)])

# %%
import pandas as pd
df = pd.DataFrame(data=results, columns=['year', 'variance'])
# Out:
#      year  variance
# 0    1880     -0.12
# 1    1881     -0.08
# 2    1882     -0.10
# 3    1883     -0.18
# 4    1884     -0.27
# ..    ...       ...
# 132  2012      0.64
# 133  2013      0.68
# 134  2014      0.74
# 135  2015      0.93
# 136  2016      0.99
#
# [137 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
df.plot(x='year');
